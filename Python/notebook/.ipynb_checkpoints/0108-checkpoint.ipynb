# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.layers import Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers

import numpy as np

#학습셋http://localhost:8888/tree의 변형을 설정하는 부분
train_datagen = ImageDataGenerator(rescale=1./255, #주어진 이미지의 크기를 설정
                                   horizontal_flip = True, #수평대칭 이미지를 50%확률로 만듬
                                   width_shift_range = 0.1, #전체크기의 15%범위에서 좌우로 이동
                                   height_shift_range=0.1, #전체크기의 15%범위에서 상하로 이동
                                   rotation_range=5, #정해진 각도만큼 회전
                                   shear_range = 0.7, #좌표 하나를 고정시키고 나머지를 이동시킴 
                                   zoom_range = 1.2, #확대 / 축소
                                   vertical_flip = True, #수직 대칭 이미지를 만듬
                                   fill_mode = 'nearest' #빈 공간을 채우는 방법
                                   # nearest : 비슷한 색으로
                                  )
train_generator = train_datagen.flow_from_directory(
    '../data/train', #학습셋이 있는 폴더 위치
    target_size = (150,150),
    batch_size = 5,
    class_mode = 'binary'
)

#테스트셋
#이미지 부풀리기 과정을 진행안함
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    '../data/train', #학습셋이 있는 폴더 위치
    target_size = (150,150),
    batch_size = 5,
    class_mode = 'binary'
)

#CNN 모델을 만들어서 적용
model = Sequential()
model.add(Conv2D(32,(3,3),input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Flatten())

model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# Found 160 images belonging to 2 classes.
# Found 160 images belonging to 2 classes.
# WARNING:tensorflow:From C:\Users\sdedu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\sdedu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
#모델실행
model.compile(loss = 'binary_crossentropy', \
              optimizer=optimizers.Adam(learning_rate = 0.0002), metrics='accuracy')

#학습의 조기중단
early_stopping_callback = EarlyStopping(monitor='var_loss', patience=5)

#모델학습
history = model.fit(train_generator, epochs=100, validation_data = test_generator,
                   validation_steps = 10, callbacks=[early_stopping_callback])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\sdedu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\sdedu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 32/32 [==============================] - ETA: 0s - loss: 1.0924 - accuracy: 0.4437WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 4s 100ms/step - loss: 1.0924 - accuracy: 0.4437 - val_loss: 0.7728 - val_accuracy: 0.3400
# Epoch 2/100
# 32/32 [==============================] - ETA: 0s - loss: 0.7242 - accuracy: 0.5437WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 82ms/step - loss: 0.7242 - accuracy: 0.5437 - val_loss: 0.6879 - val_accuracy: 0.5800
# Epoch 3/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6895 - accuracy: 0.5437WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 83ms/step - loss: 0.6895 - accuracy: 0.5437 - val_loss: 0.6928 - val_accuracy: 0.4800
# Epoch 4/100
# 32/32 [==============================] - ETA: 0s - loss: 0.7035 - accuracy: 0.5250WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 83ms/step - loss: 0.7035 - accuracy: 0.5250 - val_loss: 0.6953 - val_accuracy: 0.4200
# Epoch 5/100
# 32/32 [==============================] - ETA: 0s - loss: 0.7031 - accuracy: 0.4688WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 82ms/step - loss: 0.7031 - accuracy: 0.4688 - val_loss: 0.6911 - val_accuracy: 0.5400
# Epoch 6/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4750WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 86ms/step - loss: 0.6930 - accuracy: 0.4750 - val_loss: 0.6915 - val_accuracy: 0.5200
# Epoch 7/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5250WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 84ms/step - loss: 0.
ARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 81ms/step - loss: 0.6379 - accuracy: 0.5688 - val_loss: 0.5926 - val_accuracy: 0.7000
# Epoch 92/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6544 - accuracy: 0.5750WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 86ms/step - loss: 0.6544 - accuracy: 0.5750 - val_loss: 0.6284 - val_accuracy: 0.7000
# Epoch 93/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6511 - accuracy: 0.6062WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 82ms/step - loss: 0.6511 - accuracy: 0.6062 - val_loss: 0.6297 - val_accuracy: 0.6600
# Epoch 94/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.6062WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 83ms/step - loss: 0.6440 - accuracy: 0.6062 - val_loss: 0.5854 - val_accuracy: 0.7200
# Epoch 95/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6241 - accuracy: 0.5813WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 82ms/step - loss: 0.6241 - accuracy: 0.5813 - val_loss: 0.5413 - val_accuracy: 0.8400
# Epoch 96/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6472 - accuracy: 0.6000WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 83ms/step - loss: 0.6472 - accuracy: 0.6000 - val_loss: 0.5914 - val_accuracy: 0.8200
# Epoch 97/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6528 - accuracy: 0.6062WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 84ms/step - loss: 0.6528 - accuracy: 0.6062 - val_loss: 0.5904 - val_accuracy: 0.7200
# Epoch 98/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6457 - accuracy: 0.5562WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 83ms/step - loss: 0.6457 - accuracy: 0.5562 - val_loss: 0.6306 - val_accuracy: 0.8400
# Epoch 99/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.6187WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 86ms/step - loss: 0.6263 - accuracy: 0.6187 - val_loss: 0.5520 - val_accuracy: 0.7800
# Epoch 100/100
# 32/32 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.6313WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 3s 85ms/step - loss: 0.6359 - accuracy: 0.6313 - val_loss: 0.5576 - val_accuracy: 0.8400

# %%
#전이학습
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.layers import Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers, Input, models, layers, metrics
from tensorflow.keras.applications import VGG16

#내가가진 이미지를 학습시키기
#학습셋의 변형을 설정
train_datagen = ImageDataGenerator(rescale=1./255, #주어진 이미지의 크기를 설정
                                   horizontal_flip = True, #수평대칭 이미지를 50%확률로 만듬
                                   width_shift_range = 0.1, #전체크기의 15%범위에서 좌우로 이동
                                   height_shift_range=0.1, #전체크기의 15%범위에서 상하로 이동
                                   rotation_range=5, #정해진 각도만큼 회전
                                   shear_range = 0.7, #좌표 하나를 고정시키고 나머지를 이동시킴 
                                   zoom_range = 1.2, #확대 / 축소
                                   vertical_flip = True, #수직 대칭 이미지를 만듬
                                   fill_mode = 'nearest' #빈 공간을 채우는 방법
                                   # nearest : 비슷한 색으로
                                  )
train_generator = train_datagen.flow_from_directory(
    '../data/train', #학습셋이 있는 폴더 위치
    target_size = (150,150),
    batch_size = 5,
    class_mode = 'binary'
)

#테스트셋
#이미지 부풀리기 과정을 진행안함
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    '../data/train', #학습셋이 있는 폴더 위치
    target_size = (150,150),
    batch_size = 5,
    class_mode = 'binary'
)

#VGG16 모델
transfer_model = VGG16(weights='imagenet', include_top=False)
transfer_model.trainable = False
#transfer_model.summary()

#우리의 모델을 설정
finetune_model = models.Sequential()
finetune_model.add(transfer_model)
finetune_model.add(Flatten())
finetune_model.add(Flatten())

finetune_model.add(Dense(64))
finetune_model.add(Activation('relu'))
finetune_model.add(Dropout(0.5))


finetune_model.add(Dense(1))
finetune_model.add(Activation('sigmoid'))
finetune_model.summary()
# Out:
# Found 160 images belonging to 2 classes.
# Found 160 images belonging to 2 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 51
#      48 finetune_model.add(Flatten())
#      49 finetune_model.add(Flatten())
# ---> 51 finetune_model.add(Dense(64))
#      52 finetune_model.add(Activation('relu'))
#      53 finetune_model.add(Dropout(0.5))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\trackable\base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:148, in Dense.build(self, input_shape)
#     146 last_dim = tf.compat.dimension_value(input_shape[-1])
#     147 if last_dim is None:
# --> 148     raise ValueError(
#     149         "The last dimension of the inputs to a Dense layer "
#     150         "should be defined. Found None. "
#     151         f"Full input shape received: {input_shape}"
#     152     )
#     153 self.input_spec = InputSpec(min_ndim=2, axes={-1: last_dim})
#     154 self.kernel = self.add_weight(
#     155     "kernel",
#     156     shape=[last_dim, self.units],
#    (...)
#     161     trainable=True,
#     162 )
#
# ValueError: The last dimension of the inputs to a Dense layer should be defined. Found None. Full input shape received: (None, None)

# %%
#모델실행
finetune_model.compile(loss = 'binary_crossentropy', \
              optimizer=optimizers.Adam(learning_rate = 0.0002), metrics=['accuracy'])

#학습의 조기중단
early_stopping_callback = EarlyStopping(monitor='var_loss', patience=5)

#모델학습
history = finetune_model.fit(train_generator, epochs=100, validation_data = test_generator,
                   validation_steps = 10, callbacks=[early_stopping_callback])
# Out:
# Epoch 1/100
# 32/32 [==============================] - ETA: 0s - loss: 6.2982 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 7s 207ms/step - loss: 6.2982 - accuracy: 0.0000e+00 - val_loss: 6.3372 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 32/32 [==============================] - ETA: 0s - loss: 6.2563 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 7s 216ms/step - loss: 6.2563 - accuracy: 0.0000e+00 - val_loss: 6.5825 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 32/32 [==============================] - ETA: 0s - loss: 6.2730 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 7s 212ms/step - loss: 6.2730 - accuracy: 0.0000e+00 - val_loss: 6.5685 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 32/32 [==============================] - ETA: 0s - loss: 6.2798 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 7s 214ms/step - loss: 6.2798 - accuracy: 0.0000e+00 - val_loss: 7.2584 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 32/32 [==============================] - ETA: 0s - loss: 6.2478 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 7s 214ms/step - loss: 6.2478 - accuracy: 0.0000e+00 - val_loss: 6.3273 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 32/32 [==============================] - ETA: 0s - loss: 6.2846 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 7s 205ms/step - loss: 6.2846 - accuracy: 0.0000e+00 - val_loss: 6.8069 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 32/32 [==============================] - ETA: 0s - loss: 6.2727 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `var_loss` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 32/32 [==============================] - 7s 213ms/step - loss: 6.2727 - accuracy: 0.0000e+00 - val_loss: 6.5704 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 32/32 [==============================] - ETA: 0s - loss: 6.3110 - accuracy: 0.0000e+00
